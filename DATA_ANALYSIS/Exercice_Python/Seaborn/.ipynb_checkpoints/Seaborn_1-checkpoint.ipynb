# %% [markdown]
# # EXERCICE SEABORN

# %%
#importation des bibliothèquqees
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('D:/Users/HAJARISON/INSI/Data/_DATA/dm_office_sales.csv')
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %% [markdown]
# # SCATTER PLOT :

# %%
#Nuage de point entre la colonne sales et salary
plt.figure(figsize =(15,9))
sns.scatterplot(x='salary', y='sales', data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %% [markdown]
# ### NB :
# #### hue :  regroupe les données en fonction des valeurs distinctes dans la colonne spécifiée et attribue une couleur différente à chaque groupe.

# %%
plt.figure(figsize =(15,9))
sns.scatterplot(x='salary', y='sales', data=df, hue='division')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %%
plt.figure(figsize =(15,9))
sns.scatterplot(x='salary', y='sales', data=df, hue='work experience')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %% [markdown]
# ### NB :
# #### palette :  Carte de couleurs

# %%
plt.figure(figsize =(15,9))
sns.scatterplot(x='salary', y='sales', data=df, hue='work experience', palette='viridis')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %% [markdown]
# ### NB :
# #### style :  style de points (forme : triangle, cercle ,...)

# %%
plt.figure(figsize =(15,9))
sns.scatterplot(x='salary', y='sales', data=df, style='work experience')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %% [markdown]
# ### NB :
# #### s : taille des style

# %%
plt.figure(figsize =(15,9))
sns.scatterplot(x='salary', y='sales', data=df, style='work experience', hue='work experience', palette='viridis', s=100)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='sales'>

# %% [markdown]
# ### Exportation de figure

# %%
plt.figure(figsize =(15,9))
sns.scatterplot(x='salary', y='sales', data=df, style='work experience', hue='work experience', palette='viridis', s=100)
plt.savefig("figure1.png")
